# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data Preparation and Data Cleaning

# %%
dataset = pd.read_csv("../data_raw/StudentsPerformance.csv")

# %%
dataset.dropna(inplace=True)
dataset.to_csv("../data_clean/StudentPerformance_clean.csv", index=False)
dataset
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ### Visualizations

# %% [markdown]
# #### Gender Distribution(CountPlot)

# %%
light_palette = sns.color_palette("pastel") 
plt.figure(figsize=(6, 4))
sns.countplot(data=dataset, x='gender' , palette=light_palette)
plt.title('Gender Distribution of Students')
plt.xlabel('Gender of Students')
plt.ylabel('Count')
plt.savefig("../results/countplot_gender_distribution.png")
plt.show()

# %% [markdown]
# #### Parental level of education

# %%
parental_count = dataset['parental level of education'].value_counts()
custom_colors = ['green', 'red', 'blue', 'orange', 'yellow', 'grey']
plt.figure(figsize=(6, 4))
plt.pie(parental_count, labels=parental_count.index, autopct='%1.1f%%', colors=custom_colors)
plt.title('Pie Chart of Parental Level of Education')
plt.savefig("../results/Pie_chart.png")
plt.show()

# %% [markdown]
# #### Math Scores by Gender(Box PLot)

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=dataset, x='gender', y='math score', palette=light_palette)
plt.title('Box Plot of Math score by Gender')
plt.xlabel('Gender')
plt.ylabel('Math Score')
plt.savefig("../results/boxplot_math_scores.png")
plt.show()

# %% [markdown]
# #### Reading Scores by Gender(Box PLot)

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=dataset, x='gender', y='reading score', palette=light_palette)
plt.title('Box Plot of Reading score by Gender')
plt.xlabel('Gender')
plt.ylabel('Reading Score')
plt.savefig("../results/boxplot_reading_scores.png")
plt.show()

# %% [markdown]
# #### Writing Scores by Gender(Box PLot)
